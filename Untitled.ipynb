# %%
# !git --version
# Out:
# git version 2.43.0

# %%
# !git config --global user.name "FlorenceT.eng"

# %%
# !git config --global user.email "abigailtaks@gmail.com"

# %%
 # !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /home/jovyan/work/notebooks/data_analysis_process/assignments/itfy-data-gathering-download-florence/.git/

# %%
# !ls -la
# Out:
# total 424
# drwxr-sr-x 6 jovyan users   4096 Sep 10 20:10 .
# drwxr-sr-x 5 jovyan users   4096 Sep 10 19:51 ..
# drwxr-sr-x 7 jovyan users   4096 Sep 10 20:10 .git
# drwxr-sr-x 2 jovyan users   4096 Sep 10 20:06 .ipynb_checkpoints
# -rw-r--r-- 1 jovyan users   2866 Sep 10 20:01 README.md
# -rw-r--r-- 1 jovyan users   1370 Sep 10 20:10 Untitled.ipynb
# drwxr-sr-x 3 jovyan users   4096 Sep 10 19:51 charts
# drwxr-sr-x 4 jovyan users   4096 Sep  5 21:18 data
# -rw-r--r-- 1 jovyan users   1819 Sep  8 23:26 manifest.json
# -rw-r--r-- 1 jovyan users 397065 Sep  8 23:28 topic19_assignment_file_download.ipynb
